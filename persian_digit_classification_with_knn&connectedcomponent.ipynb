# %% [markdown]
# <a href="https://colab.research.google.com/github/baharehbehrouz/DL/blob/class/persian_digit_classification_with_knn%26connectedcomponent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">به نام خدا</div></center>
# <h1><center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">طبقه بندی نزدیکترین همسایه و K نزدیکترین همسایه</div></center></h1>

# %%
# !wget https://github.com/Alireza-Akhavan/ML-notebooks/raw/refs/heads/main/dataset/Data_hoda_full.mat -P dataset
# Out:
# --2024-10-22 02:24:14--  https://github.com/Alireza-Akhavan/ML-notebooks/raw/refs/heads/main/dataset/Data_hoda_full.mat
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Alireza-Akhavan/ML-notebooks/refs/heads/main/dataset/Data_hoda_full.mat [following]
# --2024-10-22 02:24:15--  https://raw.githubusercontent.com/Alireza-Akhavan/ML-notebooks/refs/heads/main/dataset/Data_hoda_full.mat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3989009 (3.8M) [application/octet-stream]
# Saving to: ‘dataset/Data_hoda_full.mat’
#
# Data_hoda_full.mat  100%[===================>]   3.80M  --.-KB/s    in 0.07s
#
# 2024-10-22 02:24:16 (55.2 MB/s) - ‘dataset/Data_hoda_full.mat’ saved [3989009/3989009]

# %%
# !wget https://raw.githubusercontent.com/Alireza-Akhavan/ML-notebooks/refs/heads/main/dataset.py
# Out:
# --2024-10-22 02:24:22--  https://raw.githubusercontent.com/Alireza-Akhavan/ML-notebooks/refs/heads/main/dataset.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 917 [text/plain]
# Saving to: ‘dataset.py’
#
# dataset.py          100%[===================>]     917  --.-KB/s    in 0s
#
# 2024-10-22 02:24:23 (44.4 MB/s) - ‘dataset.py’ saved [917/917]

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">لود کتابخانه‌های مورد استفاده</div>

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import numpy as np

from dataset import load_hoda

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">لود مجموعه داده (dataset)</div>

# %%
X_train, y_train, X_test, y_test = load_hoda()

# %%
X_train.shape
# Out:
# (1000, 25)

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">ایجاد طبقه بند k-nn</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# </div>

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">پیش‌بینی داده‌های آموزشی</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# </div>

# %%
neigh.predict([X_test[10]])
# Out:
# array([0], dtype=uint8)

# %%
sample = 24

X = [X_test[sample]]

predicted_class = neigh.predict(X)

print ("Sample {} is a {}, and you prediction is: {}.".format(sample, y_test[sample], predicted_class[0]))
# Out:
# Sample 24 is a 9, and you prediction is: 9.

# %%
print(neigh.predict_proba(X))
# Out:
# [[0.         0.         0.         0.         0.         0.
#   0.33333333 0.         0.         0.66666667]]

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# مثال بالا را با sample سوم تست کنید. و خروجی را تشریح کنید.
# <br>
# predict_proba چه احتمالاتی را برگردانده؟ کدام کلاس به عنوان پیش‌بینی مدل انتخاب شده؟
# </div>

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">پیش‌بینی چندین داده آزمون</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# </div>

# %%
pred_classes = neigh.predict(X_test)
pred_classes
# Out:
# array([7, 2, 3, 1, 5, 5, 4, 7, 3, 2, 0, 8, 8, 0, 3, 9, 3, 6, 7, 4, 0, 3,
#        6, 3, 9, 2, 7, 5, 2, 9, 7, 5, 5, 8, 9, 6, 5, 1, 4, 8, 8, 4, 2, 7,
#        1, 2, 7, 9, 0, 3, 7, 4, 7, 5, 2, 9, 8, 2, 9, 8, 8, 6, 6, 6, 7, 6,
#        2, 4, 1, 4, 4, 5, 9, 1, 8, 2, 0, 5, 6, 2, 4, 3, 2, 7, 7, 7, 7, 1,
#        8, 1, 7, 8, 7, 7, 8, 9, 3, 2, 3, 1, 0, 2, 9, 7, 3, 5, 5, 0, 0, 2,
#        6, 7, 9, 3, 9, 9, 8, 7, 9, 2, 5, 2, 5, 5, 9, 6, 9, 2, 0, 3, 7, 6,
#        5, 2, 9, 0, 4, 1, 8, 2, 2, 3, 0, 2, 9, 3, 8, 6, 7, 0, 9, 9, 0, 7,
#        6, 1, 4, 7, 9, 3, 7, 0, 7, 1, 9, 4, 7, 3, 4, 1, 5, 6, 7, 9, 1, 3,
#        5, 4, 5, 7, 4, 1, 3, 3, 1, 2, 5, 3, 8, 9, 6, 7, 7, 2, 3, 0, 1, 4,
#        9, 5], dtype=uint8)

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">ارزیابی</div>

# %%
np.mean(pred_classes == y_test)
# Out:
# 0.96

# %%
acc = neigh.score(X_test, y_test)
print ("Accuracy is %.2f %%" %(acc*100))
# Out:
# Accuracy is 96.00 %

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow  # Import for Colab

# Read the input image
image = cv2.imread('persian-digits.jpg', cv2.IMREAD_GRAYSCALE)

# Apply thresholding to create a binary image
_, binary_image = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY)
binary_image = 255 - binary_image

# Use connectedComponentsWithStats to obtain labels and bounding boxes
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_image, connectivity=8)

# Minimum area threshold for filtering small regions (e.g., noise)
min_area_threshold = 50  # Adjust this threshold as needed

# Iterate through each connected component
for label in range(1, num_labels):
    # Get the bounding box of the current connected component
    x, y, w, h = stats[label][:4]
    area = stats[label][4]  # Area of the region

    # Filter out very small regions (noise)
    if area < min_area_threshold:
        continue  # Ignore if the area is too small

    # Crop the connected component using the bounding box
    connected_component = binary_image[y:y+h, x:x+w]

    # Resize the connected component to 5x5 (or any size suitable for the model)
    resized_component = cv2.resize(connected_component, (5, 5))

    # Reshape the resized component to a vector (for model prediction)
    reshaped_component = resized_component.reshape(1, 25)

    # Predict the digit using the KNN model (assuming you have a KNN model)
    predicted_label = neigh.predict(reshaped_component)

    # Write the predicted digit on the original image
    font = cv2.FONT_HERSHEY_SIMPLEX
    location = (x, y - 10)  # Text location above each digit
    font_scale = 1
    color = (0, 0, 255)  # Red color for text
    thickness = 2

    # Add the predicted digit on the original image
    cv2.putText(image, str(predicted_label[0]), location, font, font_scale, color, thickness)

# Display the final image with predicted digits
cv2_imshow(image)  # Display the final image
# Out:
# <PIL.Image.Image image mode=L size=700x525>
